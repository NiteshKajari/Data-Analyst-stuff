# %%
cd downloads
# Out:
# C:\Users\hp\downloads

# %%
import pandas as pd
import numpy as np

# %%
lend = pd.read_excel('Lending Data.xlsx')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
lend
# Out:
#                           Name of Lending Institution HQ State Rank TA Ratio1  \
# 0                                                 NaN      NaN   -1        -2
# 1                               American Express Co.       NY     1   0.23829
# 2                            First Citizens Banchares      NC     2  0.187393
# 3                            Wintrust Financial Corp.      IL     3  0.168999
# 4                                       Zions Bancorp      UT     4  0.117973
# ..                                                ...      ...  ...       ...
# 92                     Charles Schwab Bk                    NV   NR         -
# 93                     Third FS&LA                          OH   NR         -
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN       NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN       NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN       NaN
#
# ...

# %%
lend.dropna()
# Out:
# Empty DataFrame
# Columns: [Name of Lending Institution, HQ State, Rank, TA Ratio1, TBL Ratio1, Amount ($1,000), Number , Lender Asset Size, Amount ($1,000).1, Number .1, Unnamed: 10, Amount ($1,000).2, Number .2, CC Amount/TA1]
# Index: []

# %%
lend
# Out:
#                           Name of Lending Institution HQ State Rank TA Ratio1  \
# 0                                                 NaN      NaN   -1        -2
# 1                               American Express Co.       NY     1   0.23829
# 2                            First Citizens Banchares      NC     2  0.187393
# 3                            Wintrust Financial Corp.      IL     3  0.168999
# 4                                       Zions Bancorp      UT     4  0.117973
# ..                                                ...      ...  ...       ...
# 92                     Charles Schwab Bk                    NV   NR         -
# 93                     Third FS&LA                          OH   NR         -
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN       NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN       NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN       NaN
#
# ...

# %%
del lend['Unnamed: 10']

# %%
lend.head()
# Out:
#   Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 0                         NaN      NaN   -1        -2         -3
# 1       American Express Co.       NY     1   0.23829   0.999544
# 2    First Citizens Banchares      NC     2  0.187393    0.49083
# 3    Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4               Zions Bancorp      UT     4  0.117973   0.260577
#
#   Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# 0              -4       -5                    -6               -7.0
# 1        16350038  3603226  >$50B                        16318089.0
# 2         3914507   117702  $10B-$50B                      378394.0
# 3         2842793   136801  $10B-$50B                      800526.0
# 4         6231770    52612  >$50B                          526206.0
#
#    Number .1  Amount ($1,000).2  Number .2 CC Amount/TA1
# 0       -8.0               -9.0      -10.0           -11
# ...

# %%
lend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  96 non-null     object
#  1   HQ State                     93 non-null     object
#  2   Rank                         94 non-null     object
#  3   TA Ratio1                    94 non-null     object
#  4   TBL Ratio1                   94 non-null     object
#  5   Amount ($1,000)              94 non-null     object
#  6   Number                       94 non-null     object
#  7   Lender Asset Size            94 non-null     object
#  8   Amount ($1,000).1            94 non-null     float64
#  9   Number .1                    94 non-null     float64
#  10  Amount ($1,000).2            94 non-null     float64
#  11  Number .2                    94 non-null     float64
#  12  CC Amount/TA1                94 non-null     object
# ...

# %%
lend = lend.dropna()

# %%
lend['TA Ratio1'].value_counts()
# Out:
# -                       4
# 0.012968043594924063    1
# 0.011236876510412061    1
# 0.019009345056153783    1
# 0.03103510194610514     1
#                        ..
# 0.04676469443587367     1
# 0.03639142784113918     1
# 0.028648540378098702    1
# 0.04853389342247428     1
# 0.02301464596524563     1
# Name: TA Ratio1, Length: 90, dtype: int64

# %%
lend
# Out:
#           Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 1               American Express Co.       NY     1   0.23829   0.999544
# 2            First Citizens Banchares      NC     2  0.187393    0.49083
# 3            Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4                       Zions Bancorp      UT     4  0.117973   0.260577
# 5             Synovus Financial Corp.      GA     5  0.162333   0.381387
# ..                                ...      ...  ...       ...        ...
# 89  USAA Svg. Bank                          NV   NR         0          -
# 90                State Street Corp.       MA    NR         -          -
# 91     E Trade Bk                           VA   NR         -          -
# 92     Charles Schwab Bk                    NV   NR         -          -
# 93     Third FS&LA                          OH   NR         -          -
#
#    Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# ...

# %%
lend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  93 non-null     object
#  1   HQ State                     93 non-null     object
#  2   Rank                         93 non-null     object
#  3   TA Ratio1                    93 non-null     object
#  4   TBL Ratio1                   93 non-null     object
#  5   Amount ($1,000)              93 non-null     object
#  6   Number                       93 non-null     object
#  7   Lender Asset Size            93 non-null     object
#  8   Amount ($1,000).1            93 non-null     float64
#  9   Number .1                    93 non-null     float64
#  10  Amount ($1,000).2            93 non-null     float64
#  11  Number .2                    93 non-null     float64
#  12  CC Amount/TA1                93 non-null     object
# ...

# %%
lend.isnull().sum()
# Out:
# Name of Lending Institution    0
# HQ State                       0
# Rank                           0
# TA Ratio1                      0
# TBL Ratio1                     0
# Amount ($1,000)                0
# Number                         0
# Lender Asset Size              0
# Amount ($1,000).1              0
# Number .1                      0
# Amount ($1,000).2              0
# Number .2                      0
# CC Amount/TA1                  0
# dtype: int64

# %%
df = lend.drop_duplicates()

# %%
df.columns
# Out:
# Index(['Name of Lending Institution', 'HQ State', 'Rank', 'TA Ratio1',
#        'TBL Ratio1', 'Amount ($1,000)', 'Number ', 'Lender Asset Size',
#        'Amount ($1,000).1', 'Number .1', 'Amount ($1,000).2', 'Number .2',
#        'CC Amount/TA1'],
#       dtype='object')

# %%
df["Lender Asset Size"].unique()
# Out:
# array(['>$50B               ', '$10B-$50B           ',
#        '>$10B               '], dtype=object)

# %%
df["Lender Asset Size"] = df["Lender Asset Size"].str.strip()

# %%
lend['Lender Asset Size'].head()
# Out:
# 1    >$50B
# 2    $10B-$50B
# 3    $10B-$50B
# 4    >$50B
# 5    $10B-$50B
# Name: Lender Asset Size, dtype: object

# %%
lend['Lender Asset Size'].head()
# Out:
# 1    >$50B
# 2    $10B-$50B
# 3    $10B-$50B
# 4    >$50B
# 5    $10B-$50B
# Name: Lender Asset Size, dtype: object

# %%
lend["Lender Asset Size"].unique
# Out:
# <bound method Series.unique of 1     >$50B
# 2     $10B-$50B
# 3     $10B-$50B
# 4     >$50B
# 5     $10B-$50B
#               ...
# 89    >$10B
# 90    >$50B
# 91    >$10B
# 92    >$10B
# 93    >$10B
# Name: Lender Asset Size, Length: 93, dtype: object>

# %%
lend['HQ State'] = lend['HQ State'].str.lower()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7060\3120528025.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lend['HQ State'] = lend['HQ State'].str.lower()

# %%
lend['CC Amount/TA1'] = lend['CC Amount/TA1'].replace('.',1000)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7060\121578328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lend['CC Amount/TA1'] = lend['CC Amount/TA1'].replace('.',1000)

# %%
lend.head()
# Out:
#   Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 1       American Express Co.       ny     1   0.23829   0.999544
# 2    First Citizens Banchares      nc     2  0.187393    0.49083
# 3    Wintrust Financial Corp.      il     3  0.168999   0.383561
# 4               Zions Bancorp      ut     4  0.117973   0.260577
# 5     Synovus Financial Corp.      ga     5  0.162333   0.381387
#
#   Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# 1        16350038  3603226  >$50B                        16318089.0
# 2         3914507   117702  $10B-$50B                      378394.0
# 3         2842793   136801  $10B-$50B                      800526.0
# 4         6231770    52612  >$50B                          526206.0
# 5         4227168    22675  $10B-$50B                      539666.0
#
#    Number .1  Amount ($1,000).2  Number .2 CC Amount/TA1
# 1  3603088.0            31949.0      138.0          0.28
# ...

# %%
lend['CC Amount/TA1'].unique #there are wide spaces so '.' not replaced with '1000'
# Out:
# <bound method Series.unique of 1        0.28
# 2         .
# 3           0
# 4           0
# 5        0.01
#        ...
# 89        .
# 90          0
# 91        .
# 92        .
# 93        .
# Name: CC Amount/TA1, Length: 93, dtype: object>

# %%
lend = lend.drop(columns=['HQ State', 'Rank']) #deleted HQ State and Rank.

# %%
lend
# Out:
#           Name of Lending Institution TA Ratio1 TBL Ratio1 Amount ($1,000)  \
# 1               American Express Co.    0.23829   0.999544        16350038
# 2            First Citizens Banchares  0.187393    0.49083         3914507
# 3            Wintrust Financial Corp.  0.168999   0.383561         2842793
# 4                       Zions Bancorp  0.117973   0.260577         6231770
# 5             Synovus Financial Corp.  0.162333   0.381387         4227168
# ..                                ...       ...        ...             ...
# 89  USAA Svg. Bank                            0          -               0
# 90                State Street Corp.          -          -               -
# 91     E Trade Bk                             -          -               -
# 92     Charles Schwab Bk                      -          -               -
# 93     Third FS&LA                            -          -               -
#
#     Number      Lender Asset Size  Amount ($1,000).1  Number .1  \
# ...

# %%
lend.columns
# Out:
# Index(['Name of Lending Institution', 'TA Ratio1', 'TBL Ratio1',
#        'Amount ($1,000)', 'Number ', 'Lender Asset Size', 'Amount ($1,000).1',
#        'Number .1', 'Amount ($1,000).2', 'Number .2', 'CC Amount/TA1'],
#       dtype='object')

# %%
lend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  93 non-null     object
#  1   TA Ratio1                    93 non-null     object
#  2   TBL Ratio1                   93 non-null     object
#  3   Amount ($1,000)              93 non-null     object
#  4   Number                       93 non-null     object
#  5   Lender Asset Size            93 non-null     object
#  6   Amount ($1,000).1            93 non-null     float64
#  7   Number .1                    93 non-null     float64
#  8   Amount ($1,000).2            93 non-null     float64
#  9   Number .2                    93 non-null     float64
#  10  CC Amount/TA1                93 non-null     object
# dtypes: float64(4), object(7)
# memory usage: 8.7+ KB

# %%
lend['TA Ratio1'] = lend['TA Ratio1'].replace('-', '0.046574')

# %%
lend
# Out:
#           Name of Lending Institution TA Ratio1 TBL Ratio1 Amount ($1,000)  \
# 1               American Express Co.    0.23829   0.999544        16350038
# 2            First Citizens Banchares  0.187393    0.49083         3914507
# 3            Wintrust Financial Corp.  0.168999   0.383561         2842793
# 4                       Zions Bancorp  0.117973   0.260577         6231770
# 5             Synovus Financial Corp.  0.162333   0.381387         4227168
# ..                                ...       ...        ...             ...
# 89  USAA Svg. Bank                            0          -               0
# 90                State Street Corp.   0.046574          -               -
# 91     E Trade Bk                      0.046574          -               -
# 92     Charles Schwab Bk               0.046574          -               -
# 93     Third FS&LA                     0.046574          -               -
#
#     Number      Lender Asset Size  Amount ($1,000).1  Number .1  \
# ...

# %%
lend['TA Ratio1']= pd.to_numeric(lend['TA Ratio1'])

# %%
df2 = lend['TA Ratio1'].mean()

# %%
df2
# Out:
# 0.04857791975730115

# %%
lend
# Out:
#           Name of Lending Institution  TA Ratio1 TBL Ratio1 Amount ($1,000)  \
# 1               American Express Co.    0.238290   0.999544        16350038
# 2            First Citizens Banchares   0.187393    0.49083         3914507
# 3            Wintrust Financial Corp.   0.168999   0.383561         2842793
# 4                       Zions Bancorp   0.117973   0.260577         6231770
# 5             Synovus Financial Corp.   0.162333   0.381387         4227168
# ..                                ...        ...        ...             ...
# 89  USAA Svg. Bank                      0.000000          -               0
# 90                State Street Corp.    0.046574          -               -
# 91     E Trade Bk                       0.046574          -               -
# 92     Charles Schwab Bk                0.046574          -               -
# 93     Third FS&LA                      0.046574          -               -
#
# ...

# %%
 lend['Lender Asset Size'].replace(regex= True, to_replace = '[^0-9]', value = '')
# Out:
# 1       50
# 2     1050
# 3     1050
# 4       50
# 5     1050
#       ...
# 89      10
# 90      50
# 91      10
# 92      10
# 93      10
# Name: Lender Asset Size, Length: 93, dtype: object

# %%
 lend['Lender Asset Size'] =  lend['Lender Asset Size'].replace(regex= True, to_replace = '[^0-9]', value = '')

# %%
lend
# Out:
#           Name of Lending Institution  TA Ratio1 TBL Ratio1 Amount ($1,000)  \
# 1               American Express Co.    0.238290   0.999544        16350038
# 2            First Citizens Banchares   0.187393    0.49083         3914507
# 3            Wintrust Financial Corp.   0.168999   0.383561         2842793
# 4                       Zions Bancorp   0.117973   0.260577         6231770
# 5             Synovus Financial Corp.   0.162333   0.381387         4227168
# ..                                ...        ...        ...             ...
# 89  USAA Svg. Bank                      0.000000          -               0
# 90                State Street Corp.    0.046574          -               -
# 91     E Trade Bk                       0.046574          -               -
# 92     Charles Schwab Bk                0.046574          -               -
# 93     Third FS&LA                      0.046574          -               -
#
# ...

# %%
 lend['Lender Asset Size']  =  lend['Lender Asset Size'] .replace(['50', '1050' , '10'],[0,1,2])

# %%
lend
# Out:
#           Name of Lending Institution  TA Ratio1 TBL Ratio1 Amount ($1,000)  \
# 1               American Express Co.    0.238290   0.999544        16350038
# 2            First Citizens Banchares   0.187393    0.49083         3914507
# 3            Wintrust Financial Corp.   0.168999   0.383561         2842793
# 4                       Zions Bancorp   0.117973   0.260577         6231770
# 5             Synovus Financial Corp.   0.162333   0.381387         4227168
# ..                                ...        ...        ...             ...
# 89  USAA Svg. Bank                      0.000000          -               0
# 90                State Street Corp.    0.046574          -               -
# 91     E Trade Bk                       0.046574          -               -
# 92     Charles Schwab Bk                0.046574          -               -
# 93     Third FS&LA                      0.046574          -               -
#
# ...

# %%
lend['CC Amount/TA1'] = lend['CC Amount/TA1'] .replace('    .  ', '')

# %%
lend['CC Amount/TA1'].unique()
# Out:
# array([0.28, '', 0, 0.01, 0.25, 0.05, 0.06, 0.1, 0.03, 0.07, 0.02],
#       dtype=object)

# %%
lend['CC Amount/TA1'] .replace('', pd.np.nan)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7060\894349699.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   lend['CC Amount/TA1'] .replace('', pd.np.nan)
# 1     0.28
# 2      NaN
# 3     0.00
# 4     0.00
# 5     0.01
#       ...
# 89     NaN
# 90    0.00
# 91     NaN
# 92     NaN
# 93     NaN
# Name: CC Amount/TA1, Length: 93, dtype: float64

# %%
lend
# Out:
#           Name of Lending Institution  TA Ratio1 TBL Ratio1 Amount ($1,000)  \
# 1               American Express Co.    0.238290   0.999544        16350038
# 2            First Citizens Banchares   0.187393    0.49083         3914507
# 3            Wintrust Financial Corp.   0.168999   0.383561         2842793
# 4                       Zions Bancorp   0.117973   0.260577         6231770
# 5             Synovus Financial Corp.   0.162333   0.381387         4227168
# ..                                ...        ...        ...             ...
# 89  USAA Svg. Bank                      0.000000          -               0
# 90                State Street Corp.    0.046574          -               -
# 91     E Trade Bk                       0.046574          -               -
# 92     Charles Schwab Bk                0.046574          -               -
# 93     Third FS&LA                      0.046574          -               -
#
# ...

# %%
lend[lend['CC Amount/TA1'] == '.']
# Out:
# Empty DataFrame
# Columns: [Name of Lending Institution, TA Ratio1, TBL Ratio1, Amount ($1,000), Number , Lender Asset Size, Amount ($1,000).1, Number .1, Amount ($1,000).2, Number .2, CC Amount/TA1]
# Index: []

# %%
lend['CC Amount/TA1'] = pd.to_numeric(lend['CC Amount/TA1'], errors='coerce')

# %%
lend['CC Amount/TA1'] = lend['CC Amount/TA1'].fillna(0)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10892\1912999973.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lend['CC Amount/TA1'] = lend['CC Amount/TA1'].fillna(0)

# %%
lend
# Out:
#           Name of Lending Institution  TA Ratio1 TBL Ratio1 Amount ($1,000)  \
# 1               American Express Co.    0.238290   0.999544        16350038
# 2            First Citizens Banchares   0.187393    0.49083         3914507
# 3            Wintrust Financial Corp.   0.168999   0.383561         2842793
# 4                       Zions Bancorp   0.117973   0.260577         6231770
# 5             Synovus Financial Corp.   0.162333   0.381387         4227168
# ..                                ...        ...        ...             ...
# 89  USAA Svg. Bank                      0.000000          -               0
# 90                State Street Corp.    0.046574          -               -
# 91     E Trade Bk                       0.046574          -               -
# 92     Charles Schwab Bk                0.046574          -               -
# 93     Third FS&LA                      0.046574          -               -
#
# ...

# %%
lend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  93 non-null     object
#  1   TA Ratio1                    93 non-null     float64
#  2   TBL Ratio1                   93 non-null     object
#  3   Amount ($1,000)              93 non-null     object
#  4   Number                       93 non-null     object
#  5   Lender Asset Size            93 non-null     int64
#  6   Amount ($1,000).1            93 non-null     float64
#  7   Number .1                    93 non-null     float64
#  8   Amount ($1,000).2            93 non-null     float64
#  9   Number .2                    93 non-null     float64
#  10  CC Amount/TA1                93 non-null     object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 8.7+ KB

# %%
lend['CC Amount/TA1'] = pd.to_numeric(lend['CC Amount/TA1'])

# %%
lend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Lending Institution  93 non-null     object
#  1   TA Ratio1                    93 non-null     float64
#  2   TBL Ratio1                   93 non-null     object
#  3   Amount ($1,000)              93 non-null     object
#  4   Number                       93 non-null     object
#  5   Lender Asset Size            93 non-null     int64
#  6   Amount ($1,000).1            93 non-null     float64
#  7   Number .1                    93 non-null     float64
#  8   Amount ($1,000).2            93 non-null     float64
#  9   Number .2                    93 non-null     float64
#  10  CC Amount/TA1                46 non-null     float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 8.7+ KB

# %%
df3 = mean_value = lend['CC Amount/TA1'].mean()

# %%
df3
# Out:
# 0.02086956521739131

# %%
lend['CC Amount/TA1'] = lend['CC Amount/TA1'] .fillna('0.02' )

# %%
lend
# Out:
#           Name of Lending Institution  TA Ratio1 TBL Ratio1 Amount ($1,000)  \
# 1               American Express Co.    0.238290   0.999544        16350038
# 2            First Citizens Banchares   0.187393    0.49083         3914507
# 3            Wintrust Financial Corp.   0.168999   0.383561         2842793
# 4                       Zions Bancorp   0.117973   0.260577         6231770
# 5             Synovus Financial Corp.   0.162333   0.381387         4227168
# ..                                ...        ...        ...             ...
# 89  USAA Svg. Bank                      0.000000          -               0
# 90                State Street Corp.    0.046574          -               -
# 91     E Trade Bk                       0.046574          -               -
# 92     Charles Schwab Bk                0.046574          -               -
# 93     Third FS&LA                      0.046574          -               -
#
# ...
